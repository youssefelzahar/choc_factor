# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
with open('segmentation_model.pkl', 'rb') as file:
    cluster = pickle.load(file)

# %%
purchase = pd.read_csv('purchase data.csv')

# %%
purchase.isnull().sum()
# Out:
# ID                   0
# Day                  0
# Incidence            0
# Brand                0
# Quantity             0
# Last_Inc_Brand       0
# Last_Inc_Quantity    0
# Price_1              0
# Price_2              0
# Price_3              0
# Price_4              0
# Price_5              0
# Promotion_1          0
# Promotion_2          0
# Promotion_3          0
# Promotion_4          0
# Promotion_5          0
# Sex                  0
# Marital status       0
# Age                  0
# Education            0
# Income               0
# Occupation           0
# Settlement size      0
# dtype: int64

# %%
def check_outliers(df):
    for col in df.columns:
        if df[col].dtype != 'object':
            q1 = df[col].quantile(0.25)
            q3 = df[col].quantile(0.75)
            iqr = q3 - q1
            lower_bound = q1 - (1.5 * iqr)
            upper_bound = q3 + (1.5 * iqr)
            outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
            print(f"Column: {col}")
            print(f"Outliers: {len(outliers)}")
    return df
check_outliers(purchase)
# Out:
# Column: ID
# Outliers: 0
# Column: Day
# Outliers: 0
# Column: Incidence
# Outliers: 14638
# Column: Brand
# Outliers: 14638
# Column: Quantity
# Outliers: 14638
# Column: Last_Inc_Brand
# Outliers: 14560
# Column: Last_Inc_Quantity
# Outliers: 14560
# Column: Price_1
# Outliers: 485
# Column: Price_2
# Outliers: 0
# Column: Price_3
# Outliers: 0
# Column: Price_4
# Outliers: 1627
# Column: Price_5
# Outliers: 5953
# Column: Promotion_1
# Outliers: 0
# Column: Promotion_2
# Outliers: 0
# Column: Promotion_3
# Outliers: 2512
# Column: Promotion_4
# Outliers: 6917
# Column: Promotion_5
# Outliers: 2105
# Column: Sex
# Outliers: 0
# Column: Marital status
# Outliers: 0
# Column: Age
# Outliers: 388
# Column: Education
# Outliers: 21532
# Column: Income
# Outliers: 2192
# Column: Occupation
# Outliers: 0
# Column: Settlement size
# Outliers: 0
#               ID  Day  Incidence  Brand  Quantity  Last_Inc_Brand  \
# 0      200000001    1          0      0         0               0
# ...

# %%
purchase["Incidence"].value_counts()
# Out:
# Incidence
# 0    44055
# 1    14638
# Name: count, dtype: int64

# %%
purchase["Brand"].value_counts()
# Out:
# Brand
# 0    44055
# 5     4978
# 2     4542
# 4     2927
# 1     1350
# 3      841
# Name: count, dtype: int64

# %%
purchase["Last_Inc_Quantity"].value_counts()
# Out:
# Last_Inc_Quantity
# 0    44133
# 1    14560
# Name: count, dtype: int64

# %%
cluster = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
purchase['Cluster'] = cluster.fit_predict(purchase)

purchase.tail()
